# %%
import pandas as pd
df=pd.read_csv('heights.csv')
df.head()
# Out:
#     Name  Height
# 0  mohan     5.9
# 1  maria     5.2
# 2  sakib     5.1
# 3    tao     5.5
# 4  virat     4.9

# %%
max_thresold=df['Height'].quantile(0.95)
max_thresold
# Out:
# 9.689999999999998

# %%
df[df['Height']>max_thresold]
# Out:
#     Name  Height
# 9  imran    14.5

# %%
min_thresold=df['Height'].quantile(0.05)
min_thresold
# Out:
# 3.6050000000000004

# %%
df[df['Height']<min_thresold]
# Out:
#       Name  Height
# 12  yoseph     1.2

# %%
df[(df['Height']>min_thresold)&(df['Height']<max_thresold)]
# Out:
#        Name  Height
# 0     mohan     5.9
# 1     maria     5.2
# 2     sakib     5.1
# 3       tao     5.5
# 4     virat     4.9
# 5    khusbu     5.4
# 6    dmitry     6.2
# 7    selena     6.5
# 8      john     7.1
# 10     jose     6.1
# 11  deepika     5.6
# 13    binod     5.5

# %%
# Ex:

# %%
import pandas as pd

# %%
dataset=pd.read_csv('AB_NYC_2019.csv')

# %%
dataset.shape
# Out:
# (48895, 16)

# %%
dataset.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
dataset.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %%
dataset['price'].quantile(0.01)
# Out:
# 30.0

# %%
dataset['price'].quantile(0.999)
# Out:
# 3000.0

# %%
min_thresold=dataset['price'].quantile(0.01)
min_thresold
# Out:
# 30.0

# %%
max_thresold=dataset['price'].quantile(0.999)
max_thresold
# Out:
# 3000.0

# %%
dataset[dataset['price']<min_thresold]
# Out:
#              id                                             name    host_id  \
# 957      375249                  Enjoy Staten Island Hospitality    1887999
# 2675    1428154              Central, Peaceful Semi-Private Room    5912572
# 2860    1620248    Large furnished 2 bedrooms- - 30 days Minimum    2196224
# 3020    1767037               Small Cozy Room Wifi & AC near JFK    9284163
# 3918    2431607                    Bright, Airy Room Share for 2    4973668
# ...         ...                                              ...        ...
# 48486  36280646                     Cable and wfi, L/G included.  272872092
# 48647  36354776    Cozy bedroom in diverse neighborhood near JFK  273393150
# 48832  36450814                         FLATBUSH HANG OUT AND GO  267223765
# 48867  36473044  The place you were dreaming for.(only for guys)  261338177
# 48868  36473253                     Heaven for you(only for guy)  261338177
#
# ...

# %%
dataset[dataset['price']>max_thresold]
# Out:
#              id                                               name    host_id  \
# 1862     826690                   Sunny, Family-Friendly 2 Bedroom    4289240
# 2698    1448703                Beautiful 1 Bedroom in Nolita/Soho      213266
# 3537    2110145                 UWS 1BR w/backyard + block from CP    2151325
# 3695    2224896                NYC SuperBowl Wk 5 Bdrs River View    11353904
# 3720    2243699                SuperBowl Penthouse Loft 3,000 sqft    1483320
# 3774    2271504                   SUPER BOWL Brooklyn Duplex Apt!!   11598359
# 3788    2281142                 Prime NYC Location for Super Bowl     1427243
# 4345    2919330                   NearWilliamsburg bridge 11211 BK   14908606
# 4376    2952861                               Photography Location    1177497
# 4377    2953058                                      Film Location    1177497
# 6530    4737930                                 Spanish Harlem Apt    1235070
# ...

# %%
new_dataset=dataset[(dataset['price']>min_thresold)&(dataset['price']<max_thresold)]

# %%
new_dataset.sample(10)
# Out:
#              id                                               name    host_id  \
# 36377  28934396    One Bedroom Apt with a pool & a gym in the bldg    6531164
# 39100  30525727                     15 minutes From Times Square!!   56778641
# 46751  35417968                                BROOKLYN 2 BEDROOMS  253493647
# 33214  26223279                                             和缘浪漫民宿  153018041
# 17554  13803517                               Large, cozy 'n sweet   80770467
# 12577   9675064          Clean Quiet 2 Bedroom Apartment,  Private   49991005
# 14374  11226811                   Sunny refuge surrounded by parks   16103591
# 44276  34147828  Sonder | Stock Exchange | Brilliant 1BR + Sofa...  219517861
# 32286  25262795                                 Brooklyn apartment  102888703
# 32185  25165611  New Yorker Room - 10 mins to Williamsburg/LES/...    1678704
#
#           host_name neighbourhood_group       neighbourhood  latitude  \
# ...

# %%
new_dataset.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.818300e+04  4.818300e+04  48183.000000  48183.000000  48183.000000
# mean   1.896272e+07  6.723035e+07     40.729155    -73.952498    148.772036
# std    1.099404e+07  7.851540e+07      0.054231      0.045894    153.594795
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420     31.000000
# 25%    9.411247e+06  7.719674e+06     40.690355    -73.983190     70.000000
# 50%    1.960306e+07  3.038419e+07     40.723280    -73.955930    110.000000
# 75%    2.910493e+07  1.072455e+08     40.763180    -73.936960    179.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990   2999.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48183.000000       48183.000000       38312.000000
# mean         7.011104          23.393915           1.373749
# std         20.526646          44.701116           1.680887
# ...

# %%
new_dataset.price.describe()
# Out:
# count    48183.000000
# mean       148.772036
# std        153.594795
# min         31.000000
# 25%         70.000000
# 50%        110.000000
# 75%        179.000000
# max       2999.000000
# Name: price, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.boxplot(new_dataset.price)
plt.show()

# %%
sns.boxplot(new_dataset.price)
# Out:
# <Axes: >

# %% [markdown]
# ###   Explore Banglore Property Prices Dataset

# %%
df=pd.read_csv('bhp.csv')
df.head()
# Out:
#                    location       size  total_sqft  bath   price  bhk  \
# 0  Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1          Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2               Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3        Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                  Kothanur      2 BHK      1200.0   2.0   51.00    2
#
#    price_per_sqft
# 0            3699
# 1            4615
# 2            4305
# 3            6245
# 4            4250

# %%
df.shape
# Out:
# (13200, 7)

# %%
df.describe()
# Out:
#          total_sqft          bath         price           bhk  price_per_sqft
# count  13200.000000  13200.000000  13200.000000  13200.000000    1.320000e+04
# mean    1555.302783      2.691136    112.276178      2.800833    7.920337e+03
# std     1237.323445      1.338915    149.175995      1.292843    1.067272e+05
# min        1.000000      1.000000      8.000000      1.000000    2.670000e+02
# 25%     1100.000000      2.000000     50.000000      2.000000    4.267000e+03
# 50%     1275.000000      2.000000     71.850000      3.000000    5.438000e+03
# 75%     1672.000000      3.000000    120.000000      3.000000    7.317000e+03
# max    52272.000000     40.000000   3600.000000     43.000000    1.200000e+07

# %%
# Explore samples that are above 99.90% percentile and below 1% percentile rank

# %%
min_thresold,max_thresold=df['price_per_sqft'].quantile([0.01,0.999])
min_thresold,max_thresold
# Out:
# (2549.0, 50959.36200000098)

# %%
df[df.price_per_sqft>max_thresold]
# Out:
#                 location       size  total_sqft  bath   price  bhk  \
# 345                other  3 Bedroom        11.0   3.0    74.0    3
# 1005               other      1 BHK        15.0   1.0    30.0    1
# 1106               other  5 Bedroom        24.0   2.0   150.0    5
# 4044      Sarjapur  Road  4 Bedroom         1.0   4.0   120.0    4
# 4924               other      7 BHK         5.0   7.0   115.0    7
# 5911         Mysore Road  1 Bedroom        45.0   1.0    23.0    1
# 6356        Bommenahalli  4 Bedroom      2940.0   3.0  2250.0    4
# 7012               other      1 BHK       650.0   1.0   500.0    1
# 7575               other      1 BHK       425.0   1.0   750.0    1
# 7799               other      4 BHK      2000.0   3.0  1063.0    4
# 8307   Bannerghatta Road      5 BHK      2500.0   4.0  1400.0    5
# 9436        Indira Nagar  4 Bedroom      2400.0   5.0  1250.0    4
# 11447         Whitefield  4 Bedroom        60.0   4.0   218.0    4
# ...

# %%
df[df.price_per_sqft<min_thresold]
# Out:
#                  location   size  total_sqft  bath  price  bhk  price_per_sqft
# 20                Kengeri  1 BHK       600.0   1.0  15.00    1            2500
# 130       Electronic City  2 BHK       880.0   1.0  16.50    2            1875
# 169              Attibele  1 BHK       450.0   1.0  11.00    1            2444
# 247            Chandapura  2 BHK       800.0   1.0  20.00    2            2500
# 250                 other  2 BHK       900.0   2.0  22.50    2            2500
# ...                   ...    ...         ...   ...    ...  ...             ...
# 12458               other  1 BHK      2559.0   1.0  55.00    1            2149
# 12463          Chandapura  1 BHK       410.0   1.0  10.00    1            2439
# 12532     Electronic City  2 BHK      1125.0   2.0  28.13    2            2500
# 12555  Kumaraswami Layout  2 BHK      1200.0   2.0  29.00    2            2416
# 12897         Kammasandra  3 BHK      1616.0   3.0  40.00    3            2475
#
# [127 rows x 7 columns]

# %% [markdown]
# ### Remove outliers

# %%
df1=df[(df.price_per_sqft>min_thresold)&(df.price_per_sqft<max_thresold)]

# %%
df1.sample(10)
# Out:
#                     location       size  total_sqft  bath  price  bhk  \
# 13153  Raja Rajeshwari Nagar      1 BHK       510.0   1.0   22.0    1
# 7882               Bellandur      3 BHK      1767.0   3.0  109.0    3
# 1053    2nd Stage Nagarbhavi  6 Bedroom      2400.0   8.0  450.0    6
# 11910         Subramanyapura      3 BHK      1800.0   3.0   80.0    3
# 11780               Panathur      2 BHK      1075.0   2.0   60.0    2
# 5983              Whitefield      3 BHK      1330.0   2.0   55.0    3
# 7375            Channasandra  4 Bedroom      1800.0   4.0  300.0    4
# 2462               Bellandur      2 BHK      1220.0   2.0   60.0    2
# 11229       Old Airport Road      2 BHK      1184.0   2.0   78.0    2
# 12106             R.T. Nagar      2 BHK      1325.0   2.0   52.0    2
#
#        price_per_sqft
# 13153            4313
# 7882             6168
# 1053            18750
# 11910            4444
# 11780            5581
# 5983             4135
# 7375            16666
# ...

# %%
df1.shape
# Out:
# (13050, 7)

# %%
df1.describe()
# Out:
#          total_sqft          bath         price           bhk  price_per_sqft
# count  13050.000000  13050.000000  13050.000000  13050.000000    13050.000000
# mean    1537.980823      2.696092    112.325274      2.804521     6704.440077
# std      960.142208      1.334668    145.826665      1.289272     4138.596163
# min      250.000000      1.000000      8.000000      1.000000     2550.000000
# 25%     1100.000000      2.000000     50.000000      2.000000     4296.000000
# 50%     1275.000000      2.000000     72.000000      3.000000     5461.500000
# 75%     1672.000000      3.000000    120.000000      3.000000     7338.750000
# max    30400.000000     40.000000   3600.000000     43.000000    50349.000000
